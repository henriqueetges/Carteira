# %%
import pandas as pd
from requests import get
import os
from pyaml_env import parse_config
from datetime import datetime
import psycopg2

# %%
API_KEY = parse_config('env.yml')['Environments'][0]['brapi_key']
DB_USER = parse_config('env.yml')['Environments'][0]['database_user']
DB_PW = parse_config('env.yml')['Environments'][0]['database_pw']
DB_NAME = parse_config('env.yml')['Environments'][0]['database_name']
DB_HOST = parse_config('env.yml')['Environments'][0]['database_url']
DB_PORT = parse_config('env.yml')['Environments'][0]['database_port']

# %%
def connect():
    params = {
        "dbname": "inv", /n /n /n
        "user": DB_USER,
        "password": DB_PW,
        "host": DB_HOST,
        "port": DB_PORT,
    }
    try:
        conn = psycopg2.connect(**params)
        return conn

    except (psycopg2.Error, Exception) as e:
        print(e)

# %%
class Stock:
    # TO DO 
    # CREATE A WAY THAT WHENEVER A NEW TRANSACTION IS DONE, IT FETCHES THE INFORMATION ABOUT IT'S STOCK (INFO, HISTORICALS, QUOTE)
    instances = []
    def __init__(self, ticker):
        self.ticker = ticker
        self.url = f'https://brapi.dev/api/quote/{self.ticker}'       
    
    def GetStockInfo(self):
        params = {
            'modules': 'summaryProfile',
            'token': API_KEY,}
        url = self.url
        try:
            req = get(url, params=params)
            data = req.json()
            df = pd.DataFrame(data['results'])
            info = pd.json_normalize(df['summaryProfile'])
            return info
        except Exception as e:
            print(e)

    def GetStockQuote(self):
        params = {
            'token': API_KEY}
        try:
            req = get(self.url, params=params)
            data = req.json()
            return pd.DataFrame(data['results'])
        except Exception as e:
            print(e)      

    def GetHistoricalQuote(self):
        params = {
            'token': API_KEY,
            'range':'3mo',
            'interval':'1d',}
        try:
            req = get(self.url, params=params)
            data = req.json()
            results = pd.json_normalize(data,  'results')
            df = pd.DataFrame(results['historicalDataPrice'][0])
            df['date'], df['ticker'] = df['date'].astype('datetime64[s]'), self.ticker
            return df
        except Exception as e:
            print(e)

    def TransformQuotes(data):   
        df = pd.DataFrame(data['results'])
        return df

# %%
class Transacao:
    instances = []
    def __init__(self, ticker: str, preco: float, quantidade: int, data: datetime.date = None):
        self.ticker = ticker
        self.price = preco
        self.quantity = quantidade
        self.date = data if data else datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        Transacao.instances.append(self)
        try:
            self.insert_into_db()
        except Exception as e:
            print(f"Error inserting transaction: {e}")

    def __repr__(self):
        return f"Transacao do {self.ticker} ao preço de {self.price} e {self.quantity} unidades, feita na data de'{self.date}'"


    def insert_into_db(self):
        with connect() as conn:
            with conn.cursor() as cur:
                insert_query = """
                INSERT INTO inv.public.transac(ticker, price, quantity, transac_date)
                VALUES (%s, %s, %s, %s)
                """
                cur.execute(insert_query, (self.ticker, self.price, self.quantity, self.date))
                conn.commit()
                
    @classmethod
    def get_from_backend(cls):
        cls.instances.clear()
        conn = connect()
        results = pd.read_sql_query("SELECT * FROM inv.public.transac", conn)
        for _, row in results.iterrows():
            Transacao(ticker=row['ticker'], 
                preco=row['price'],
                quantidade=row['quantity'],
                data=row['transac_date'])
        return Transacao.instances

# %%
information_data = []
stocks = set([i.ticker for i in Transacao.instances])

for ticker in stocks:
    stock = Stock(ticker)
    data = stock.GetStockInfo()
    data['ticker'] = ticker
    information_data.append(data)
final = pd.concat(information_data)
final.head(20)
# Out:
#                                     address1  \
# 0      Brigadeiro LuAs AntA nio Avenue, 1343
# 0                   Banco do Brasil Building
# 0                    Eldorado Business Tower
# 0                   EdifIcio Banco do Brasil
# 0             Avenida Henrique Valadares, 28
# 0  Parque Cidade Corporate Building, Tower A
# 0                Av. Dra. Ruth Cardoso, 8501
# 0                       Rua da Quitanda, 196
# 0       Avenida Bernardo Vasconcelos, n° 377
# 0                      Praia de Botafogo 186
# 0                          20, Genesis Close
# 0      Rua Jorge Figueiredo Corrêa, nº 1.632
#
#                                             address2            city state  \
# 0                                          9th Floor       São Paulo    SP
# 0  3rd Floor North Wing, Block 05, Lot B, South T...        Brasília    DF
# 0  30th floor Avenida Dra. Ruth Cardoso, No. 8,50...       São Paulo    SP
# 0  Quadra 5, Lote B Autarquias Norte Federal Dist...        Brasília    DF
# 0                                         19th floor  Rio De Janeiro    RJ
# 0  Rooms 1.201, 1.202,1.204, 1.205 SCS, BLOCK 09,...        Brasília    DF
# 0                                          8th floor       São Paulo    SP
# 0                                   9th Floor Centro  Rio De Janeiro    RJ
# 0                                Bairro Cachoeirinha  Belo Horizonte    MG
# 0               offices 1101, 1701 and 1801 Botafogo  Rio De Janeiro    RJ
# 0                                        George Town    Grand Cayman   NaN
# 0                         Jardim Professora TarcIlia        Campinas    SP
#
#          zip         country            phone  \
# 0  01317-910          Brazil  55 11 3177 7014
# 0        NaN          Brazil              NaN
# 0  05425-070          Brazil  55 11 3040 6874
# 0        NaN          Brazil  55 80 0729 5285
# 0  20241-030          Brazil              NaN
# 0  70308-200          Brazil  55 61 3426 1000
# 0  05425-070          Brazil  55 11 3094 6300
# 0  20091-005          Brazil  55 21 2514 4637
# 0  31150-000          Brazil  55 31 3247 7024
# 0  22250-145          Brazil  55 21 3485 5000
# 0  KY-1-1208  Cayman Islands              NaN
# 0  13087-397          Brazil  55 19 3756 8458
#
#                                 website                          industry  \
# 0              https://www.ultra.com.br    Oil & Gas Refining & Marketing
# 0     https://www.bbseguridaderi.com.br           Insurance - Diversified
# 0                   https://embraer.com               Aerospace & Defense
# 0                 https://www.bb.com.br                  Banks - Regional
# 0              https://petrobras.com.br              Oil & Gas Integrated
# 0  https://www.equatorialenergia.com.br    Utilities - Regulated Electric
# 0               https://www2.gerdau.com                             Steel
# 0            https://www.eletrobras.com             Utilities - Renewable
# 0              https://www.localiza.com         Rental & Leasing Services
# 0                  https://www.vale.com  Other Industrial Metals & Mining
# 0                 https://www.xpinc.com                   Capital Markets
# 0               https://www.cpfl.com.br    Utilities - Regulated Electric
#
#                       industryKey                      industryDisp  \
# 0      oil-gas-refining-marketing    Oil & Gas Refining & Marketing
# 0           insurance-diversified           Insurance - Diversified
# 0               aerospace-defense               Aerospace & Defense
# 0                  banks-regional                  Banks - Regional
# 0              oil-gas-integrated              Oil & Gas Integrated
# 0    utilities-regulated-electric    Utilities - Regulated Electric
# 0                           steel                             Steel
# 0             utilities-renewable             Utilities - Renewable
# 0         rental-leasing-services         Rental & Leasing Services
# 0  other-industrial-metals-mining  Other Industrial Metals & Mining
# 0                 capital-markets                   Capital Markets
# 0    utilities-regulated-electric    Utilities - Regulated Electric
#
#                sector           sectorKey          sectorDisp  \
# 0              Energy              energy              Energy
# 0  Financial Services  financial-services  Financial Services
# 0         Industrials         industrials         Industrials
# 0  Financial Services  financial-services  Financial Services
# 0              Energy              energy              Energy
# 0           Utilities           utilities           Utilities
# 0     Basic Materials     basic-materials     Basic Materials
# 0           Utilities           utilities           Utilities
# 0         Industrials         industrials         Industrials
# 0     Basic Materials     basic-materials     Basic Materials
# 0  Financial Services  financial-services  Financial Services
# 0           Utilities           utilities           Utilities
#
#                                  longBusinessSummary  fullTimeEmployees  \
# 0  Ultrapar Participações S.A., through its subsi...            10126.0
# 0  BB Seguridade Participações S.A., through its ...              222.0
# 0  Embraer S.A., together with its subsidiaries, ...            19179.0
# 0  Banco do Brasil S.A., together with its subsid...                NaN
# 0  Petróleo Brasileiro S.A. - Petrobras explores,...            46730.0
# 0  Equatorial Energia S.A., through its subsidiar...                NaN
# 0  Gerdau S.A., together with its subsidiaries, o...                NaN
# 0  Centrais Elétricas Brasileiras S.A. - Eletrobr...             8328.0
# 0  Localiza Rent a Car S.A. engages in car and fl...            21091.0
# 0  Vale S.A., together with its subsidiaries, pro...                NaN
# 0  XP Inc. provides financial products and servic...             6834.0
# 0  CPFL Energia S.A. engages in the generation, t...                NaN
#
#   companyOfficers                                          irWebsite  \
# 0              []       http://www.ultra.com.br/ri/english/index.htm
# 0              []                                                NaN
# 0              []  http://ri.embraer.com.br/default.aspx?linguage...
# 0              []                                                NaN
# 0              []                                                NaN
# 0              []                                                NaN
# 0              []                                                NaN
# 0              []                                                NaN
# 0              []                                                NaN
# 0              []                                                NaN
# 0              []                                                NaN
# 0              []                                                NaN
#
#   executiveTeam  ticker
# 0            []   UGPA3
# 0            []   BBSE3
# 0            []   EMBR3
# 0            []   BBAS3
# 0            []   PETR4
# 0            []   EQTL3
# 0            []   GGBR3
# 0            []   ELET3
# 0            []   RENT3
# 0            []   VALE3
# 0            []  XPBR31
# 0            []   CPFE3

# %%
with connect() as conn:
    with conn.cursor() as cur:
        query = """
                INSERT INTO inv.public.stock_info(
                    address_one, 
                    address_two, 
                    city, 
                    state, 
                    zip, 
                    country, 
                    phone, 
                    industry, 
                    industry_key, 
                    industry_disp, 
                    sector, 
                    sector_key, 
                    sector_disp, 
                    bus_summary, 
                    employees, 
                    website, 
                    ticker  )
                VALUES (%s, %s, %s, %s,%s, %s, %s, %s,%s, %s, %s, %s,%s, %s, %s, %s,%s)""" 
        for row in final.itertuples():
                cur.execute(query, (row.address1, row.address2, row.city, row.state, row.zip, row.country, row.phone,  row.industry, row.industryKey, row.industryDisp, row.sector, row.sectorKey, row.sectorDisp, row.longBusinessSummary, row.fullTimeEmployees, row.irWebsite, row.ticker))
